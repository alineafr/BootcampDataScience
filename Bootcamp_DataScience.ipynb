# %% [markdown]
# <a href="https://colab.research.google.com/github/alineafr/BootcampDataScience/blob/main/Bootcamp_DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A185214189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
# Out:
# <ipython-input-9-96a5fb43b3f1>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("/content/A185214189_28_143_208.csv", encoding="ISO-8859-1",

# %%
dados
# Out:
#       Unidade da Federação    2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0              11 Rondônia  1388528.39   2931283.42   1541682.52   1525314.96
# 1                  12 Acre   902416.00   1497206.26   1794028.48   1730469.42
# 2              13 Amazonas  4735529.42   7118990.57   8196635.49   8259378.42
# 3               14 Roraima   657889.53    777939.31    718688.03    839994.39
# 4                  15 Pará 18864744.11  19553758.20  21937342.70  20842829.69
# 5                 16 Amapá  1120973.34   1268740.33    974651.24   1141137.32
# 6             17 Tocantins  3441592.69   4985688.85   6205612.60   4984482.09
# 7              21 Maranhão 10723506.39  13559679.41  13985142.36  14809416.46
# 8                 22 Piauí  7985142.43  10079928.25  10298372.45  10775976.33
# 9                 23 Ceará 15539821.90  25735101.55  28724625.75  30676457.06
# 10  24 Rio Grande do Norte  5947814.08   9509755.83  10352238.59  10855108.50
# ...

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()

# %%
dados["2008/Ago"]

# %%
dados["2008/Ago"].mean()

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor Total por Unidade da Federação em Agosto de 2008")
plt.show()

# %%
ax = dados.plot(x="Unidade da Federação", y="2021/Mar", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor Total por Unidade da Federação em Agosto de 2008")
plt.show()

# %%
lista = ["Norte","Norte","Norte","Norte","Norte","Norte","Norte",
                   "Nordeste","Nordeste","Nordeste","Nordeste","Nordeste","Nordeste","Nordeste","Nordeste","Nordeste",
                   "Sudeste","Sudeste","Sudeste","Sudeste",
                   "Sul","Sul","Sul"
                   "Centro-Oeste","Centro-Oeste","Centro-Oeste","Centro-Oeste"]

# %%
list = []

# %%
dados["Região"] = dados(lista)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b2c69b4d3595> in <cell line: 1>()
# ----> 1 dados["Região"] = dados(lista)
#
# TypeError: 'DataFrame' object is not callable
